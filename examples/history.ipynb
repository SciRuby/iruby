# %%
:out1
# Out:
# :out1

# %%
:out2
# Out:
# :out2

# %%
:out3
# Out:
# :out3

# %%
puts _iii
puts _ii
puts _i

puts _i1
puts _i2
puts _i3

puts _ih[1]
puts _ih[2]
puts _ih[3]

puts In[1]
puts In[2]
puts In[3]

puts In[-3]
puts In[-2]
puts In[-1]

puts ___
puts __
puts _

puts _1
puts _2
puts _3

puts _oh[1]
puts _oh[2]
puts _oh[3]

puts Out[1]
puts Out[2]
puts Out[3]

puts Out[-3]
puts Out[-2]
puts Out[-1]
# Out:
# :out1
# :out2
# :out3
# :out1
# :out2
# :out3
# :out1
# :out2
# :out3
# :out1
# :out2
# :out3
# :out1
# :out2
# :out3
# out1
# out2
# out3
# out1
# out2
# out3
# out1
# out2
# out3
# out1
# out2
# out3
# out1
# out2
# out3
