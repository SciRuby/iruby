# %% [markdown]
# # Standard input and output

# %%
puts 'Hello, world!'
# Out:
# Hello, world!

# %%
$stdout.puts 'stdout'
$stderr.puts 'stderr'
# Out:
# stdout
# stderr

# %%
print "print\n"
$stdout.write "write\n"
# Out:
# print
# write
